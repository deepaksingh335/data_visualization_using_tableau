# %%
import pandas as pd

# %%
df = pd.read_csv('2008.csv/2008.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7009728 entries, 0 to 7009727
# Data columns (total 29 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# ...

# %%
carr = pd.read_csv('carriers.csv')
airports = pd.read_csv('airports.csv')

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1491 entries, 0 to 1490
# Data columns (total 2 columns):
# Code           1490 non-null object
# Description    1491 non-null object
# dtypes: object(2)
# memory usage: 23.4+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3376 entries, 0 to 3375
# Data columns (total 7 columns):
# iata       3376 non-null object
# airport    3376 non-null object
# city       3364 non-null object
# state      3364 non-null object
# country    3376 non-null object
# lat        3376 non-null float64
# long       3376 non-null float64
# dtypes: float64(2), object(5)
# memory usage: 184.7+ KB

# %%
carr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1491 entries, 0 to 1490
# Data columns (total 2 columns):
# Code           1490 non-null object
# Description    1491 non-null object
# dtypes: object(2)
# memory usage: 23.4+ KB

# %%
airports
# Out:
#      iata                       airport                city state  \
# 0     00M                      Thigpen          Bay Springs    MS
# 1     00R          Livingston Municipal          Livingston    TX
# 2     00V                   Meadow Lake    Colorado Springs    CO
# 3     01G                  Perry-Warsaw               Perry    NY
# 4     01J              Hilliard Airpark            Hilliard    FL
# 5     01M             Tishomingo County             Belmont    MS
# 6     02A                   Gragg-Wade              Clanton    AL
# 7     02C                       Capitol          Brookfield    WI
# 8     02G             Columbiana County      East Liverpool    OH
# 9     03D              Memphis Memorial             Memphis    MO
# 10    04M                Calhoun County           Pittsboro    MS
# 11    04Y              Hawley Municipal              Hawley    MN
# 12    05C        Griffith-Merrillville             Griffith    IN
# ...

# %%
carr
# Out:
#         Code                                   Description
# 0        02Q                                 Titan Airways
# 1        04Q                            Tradewind Aviation
# 2        05Q                           Comlux Aviation, AG
# 3        06Q                 Master Top Linhas Aereas Ltd.
# 4        07Q                           Flair Airlines Ltd.
# 5        09Q                                Swift Air, LLC
# 6        0BQ                                           DCA
# 7        0CQ                          ACM AIR CHARTER GmbH
# 8        0FQ          Maine Aviation Aircraft Charter, LLC
# 9        0GQ  Inter Island Airways, d/b/a Inter Island Air
# 10       0HQ       Polar Airlines de Mexico d/b/a Nova Air
# 11        0J                                    JetClub AG
# 12       0JQ                               Vision Airlines
# 13       0KQ                Mokulele Flight Services, Inc.
# 14       0LQ                             Metropix UK, LLP.
# ...

# %%
df['WeatherDelay'].value_counts()
# Out:
# 0.0       1424750
# 10.0         2870
# 6.0          2739
# 15.0         2724
# 7.0          2528
# 8.0          2522
# 5.0          2377
# 9.0          2302
# 20.0         2089
# 4.0          2077
# 3.0          2054
# 11.0         2026
# 2.0          2002
# 12.0         1986
# 16.0         1962
# 17.0         1935
# 1.0          1869
# 13.0         1868
# 14.0         1867
# 18.0         1811
# 19.0         1669
# 25.0         1611
# 30.0         1466
# 21.0         1460
# 22.0         1408
# 23.0         1359
# 24.0         1264
# 26.0         1231
# 28.0         1210
# 27.0         1149
#            ...
# 646.0           1
# 644.0           1
# 642.0           1
# 640.0           1
# 630.0           1
# 628.0           1
# 457.0           1
# 613.0           1
# 610.0           1
# 607.0           1
# 600.0           1
# 598.0           1
# 597.0           1
# 388.0           1
# 391.0           1
# 586.0           1
# 584.0           1
# 581.0           1
# 579.0           1
# ...

# %%
[df['WeatherDelay'].isnull()]
# Out:
# [0           True
#  1           True
#  2           True
#  3           True
#  4          False
#  5           True
#  6          False
#  7           True
#  8           True
#  9           True
#  10          True
#  11         False
#  12          True
#  13          True
#  14          True
#  15          True
#  16         False
#  17          True
#  18         False
#  19         False
#  20          True
#  21         False
#  22          True
#  23          True
#  24          True
#  25          True
#  26         False
#  27          True
#  28          True
#  29          True
#             ...
#  7009698     True
#  7009699    False
#  7009700     True
#  7009701    False
#  7009702     True
#  7009703     True
#  7009704     True
#  7009705    False
#  7009706     True
#  7009707     True
#  7009708     True
#  7009709    False
#  7009710    False
#  7009711     True
#  7009712     True
#  7009713     True
#  7009714     True
#  7009715    False
#  7009716     True
# ...

# %%
df['WeatherDelay'].fillna(0, inplace=True)

# %%
df['NASDelay'].fillna(0, inplace=True)

# %%
df['SecurityDelay'].fillna(0, inplace=True)

# %%
df['LateAircraftDelay'].fillna(0, inplace=True)

# %%
df['Cancelled'].value_counts()
# Out:
# 0    6872294
# 1     137434
# Name: Cancelled, dtype: int64

# %%
df['CancellationCode'].value_counts()
# Out:
# B    54904
# A    54330
# C    28188
# D       12
# Name: CancellationCode, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7009728 entries, 0 to 7009727
# Data columns (total 29 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# ...

# %%
df['ArrDelay'].fillna(0, inplace=True)

# %%
df['DepDelay'].fillna(0, inplace=True)

# %%
df_clean = pd.merge(left=df, right=airports, left_on='Origin', right_on='iata', how='left')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7009728 entries, 0 to 7009727
# Data columns (total 36 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Origin               object
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# ...

# %%
df_clean[['Origin','iata','airport','city','state']]
# Out:
#         Origin iata                            airport             city state
# 0          IAD  IAD    Washington Dulles International        Chantilly    VA
# 1          IAD  IAD    Washington Dulles International        Chantilly    VA
# 2          IND  IND         Indianapolis International     Indianapolis    IN
# 3          IND  IND         Indianapolis International     Indianapolis    IN
# 4          IND  IND         Indianapolis International     Indianapolis    IN
# 5          IND  IND         Indianapolis International     Indianapolis    IN
# 6          IND  IND         Indianapolis International     Indianapolis    IN
# 7          IND  IND         Indianapolis International     Indianapolis    IN
# 8          IND  IND         Indianapolis International     Indianapolis    IN
# 9          IND  IND         Indianapolis International     Indianapolis    IN
# 10         IND  IND         Indianapolis International     Indianapolis    IN
# ...

# %%
columns=['Origin','iata','airport','country','lat','long']
df_clean = df_clean.drop(columns, axis=1)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7009728 entries, 0 to 7009727
# Data columns (total 30 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# city                 object
# ...

# %%
df_clean= df_clean.rename(columns = {"city":"origin_city","state":"origin_state"})

# %%
df_clean = pd.merge(left=df_clean, right=airports, left_on='Dest', right_on='iata', how='left')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7009728 entries, 0 to 7009727
# Data columns (total 37 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Dest                 object
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# origin_city          object
# ...

# %%
df_clean[['Dest','iata','airport','city','state']]
# Out:
#         Dest iata                               airport             city state
# 0        TPA  TPA                  Tampa International             Tampa    FL
# 1        TPA  TPA                  Tampa International             Tampa    FL
# 2        BWI  BWI    Baltimore-Washington International        Baltimore    MD
# 3        BWI  BWI    Baltimore-Washington International        Baltimore    MD
# 4        BWI  BWI    Baltimore-Washington International        Baltimore    MD
# 5        JAX  JAX            Jacksonville International     Jacksonville    FL
# 6        LAS  LAS                McCarran International        Las Vegas    NV
# 7        LAS  LAS                McCarran International        Las Vegas    NV
# 8        MCI  MCI             Kansas City International      Kansas City    MO
# 9        MCI  MCI             Kansas City International      Kansas City    MO
# 10       MCO  MCO                 Orlando International          Orlando    FL
# ...

# %%
columns=['Dest','iata','airport','country','lat','long']
df_clean = df_clean.drop(columns, axis=1)

# %%
df_clean= df_clean.rename(columns = {"city":"dest_city","state":"dest_state"})

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7009728 entries, 0 to 7009727
# Data columns (total 31 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# origin_city          object
# origin_state         object
# ...

# %%
df_clean = pd.merge(left=df_clean, right=carr, left_on='UniqueCarrier', right_on='Code', how='left')

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7009728 entries, 0 to 7009727
# Data columns (total 33 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# UniqueCarrier        object
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# origin_city          object
# origin_state         object
# ...

# %%
df_clean[['origin_city','origin_state','dest_city','dest_state','UniqueCarrier','Code','Description']]
# Out:
#              origin_city origin_state        dest_city dest_state  \
# 0              Chantilly           VA            Tampa         FL
# 1              Chantilly           VA            Tampa         FL
# 2           Indianapolis           IN        Baltimore         MD
# 3           Indianapolis           IN        Baltimore         MD
# 4           Indianapolis           IN        Baltimore         MD
# 5           Indianapolis           IN     Jacksonville         FL
# 6           Indianapolis           IN        Las Vegas         NV
# 7           Indianapolis           IN        Las Vegas         NV
# 8           Indianapolis           IN      Kansas City         MO
# 9           Indianapolis           IN      Kansas City         MO
# 10          Indianapolis           IN          Orlando         FL
# 11          Indianapolis           IN          Orlando         FL
# 12          Indianapolis           IN          Chicago         IL
# ...

# %%
columns=['UniqueCarrier','Code']
df_clean = df_clean.drop(columns, axis=1)
df_clean= df_clean.rename(columns = {"Description":"airline_carrier"})

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7009728 entries, 0 to 7009727
# Data columns (total 31 columns):
# Year                 int64
# Month                int64
# DayofMonth           int64
# DayOfWeek            int64
# DepTime              float64
# CRSDepTime           int64
# ArrTime              float64
# CRSArrTime           int64
# FlightNum            int64
# TailNum              object
# ActualElapsedTime    float64
# CRSElapsedTime       float64
# AirTime              float64
# ArrDelay             float64
# DepDelay             float64
# Distance             int64
# TaxiIn               float64
# TaxiOut              float64
# Cancelled            int64
# CancellationCode     object
# Diverted             int64
# CarrierDelay         float64
# WeatherDelay         float64
# NASDelay             float64
# SecurityDelay        float64
# LateAircraftDelay    float64
# origin_city          object
# origin_state         object
# dest_city            object
# ...

# %%
df_clean.to_csv('flights_final.csv', index=False, encoding = 'utf-8')

# %%
df_master = pd.read_csv('twitter_archive_master_final.csv')
df_master.info(
